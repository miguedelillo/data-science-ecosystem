# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science and Ecosystem are summarized.

# %% [markdown]
# *Objetives:*
# * List popular lenguages for Data Science.
# * List popular libraries for Data Science.
# * List popular tools for Data Science.

# %% [markdown]
# Some of the popular lenguages that Data Scientist use are:
# 1. Python.
# 2. R.
# 3. Julia.
# 4. SQL.
# 5. Java.
# 6. C++.

# %% [markdown]
# Some of the commonly used libraries used by Data Scientist include:
# 1. Pandas.
# 2. NumPy.
# 3. MatPlotLib.
# 4. TensorFlow.

# %% [markdown]
# |Data Science Tools|
# |------|
# |Jupyter Labs|
# |R Studio|
# |Vistual Studio Code|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
## This is a simple arithemtic expression to multiply then add integers.
(3*4)+5
# Out:
# 17

# %%
## This will convert 200 minutes to hours by dividing by 60.
200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Miguel Angel De Lillo.
